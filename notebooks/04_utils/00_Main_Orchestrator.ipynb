# %%
try:
    print("Starting Bronze Ingestion")
    dbutils.notebook.run("02_bronze_sales_ingestion", 0)

    print("Starting Silver Transformations")
    dbutils.notebook.run("03_silver_sales_transformation", 0)

    print("Starting Gold Dimensions")
    dbutils.notebook.run("05_gold_dim_customers", 0)
    dbutils.notebook.run("06_gold_dim_products", 0)
    dbutils.notebook.run("07_gold_dim_payment", 0)
    dbutils.notebook.run("08_gold_dim_date", 0)

    print("Starting Gold Fact Table")
    dbutils.notebook.run("09_gold_fact_sales", 0)

except Exception as e:
    print(f"Pipeline failed: {e}")
    raise e
