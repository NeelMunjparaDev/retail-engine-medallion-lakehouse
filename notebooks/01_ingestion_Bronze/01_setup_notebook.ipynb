-- %%
CREATE SCHEMA IF NOT EXISTS retail_project.bronze

-- %%
CREATE SCHEMA IF NOT EXISTS retail_project.silver

-- %%
CREATE SCHEMA IF NOT EXISTS retail_project.gold

-- %%
CREATE TABLE IF NOT EXISTS retail_project.silver.sales_errors (
    order_id STRING,
    cust_id STRING,
    product_name STRING,
    category STRING,
    city STRING,
    region STRING,
    base_price DOUBLE,
    discount_amount DOUBLE,
    final_price DOUBLE,
    order_status STRING,
    payment_mode STRING,
    payment_status STRING,
    found_us_via STRING,
    event_ts TIMESTAMP,
    row_hash STRING,
    source_file STRING,
    ingested_at TIMESTAMP,
    _batch_id LONG,
    silver_processed_at TIMESTAMP
)
USING DELTA;

-- %%
CREATE EXTERNAL VOLUME retail_project.bronze.sales_data_landing
LOCATION 's3://n-retail-data-lake/landing/';
